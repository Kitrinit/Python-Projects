# %% [markdown]
# # Changelog
#
# Version 4
# - Trying 1 week Forecast
# - Implementing Streamlit

# %% [markdown]
# # Importing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2

# %%
user1_df = pd.read_csv("user1_presence_data_60.csv")
user2_df = pd.read_csv("user2_presence_data_60.csv")

# %%
# Convert 'time' column to datetime
user1_df["time"] = pd.to_datetime(user1_df["time"])
user2_df["time"] = pd.to_datetime(user2_df["time"])

# %%
# Merge datasets directly by time to ensure each row contains both users' states
merged_df = pd.merge(user1_df, user2_df, on="time", suffixes=("_user1", "_user2"))

# %% [markdown]
# # Feature Engineering

# %%
# Extract hour, minute, day
merged_df["hour"] = merged_df["time"].dt.hour
merged_df["minute"] = merged_df["time"].dt.minute
merged_df["day_of_week"] = merged_df["time"].dt.dayofweek  # Monday=0 ... Sunday=6
merged_df["is_weekend"] = merged_df["day_of_week"].isin([5,6]).astype(int)

# %%
merged_df
# Out:
#                             time  state_user1  state_user2  hour  minute  \
# 0      2022-04-24 00:01:00+00:00  living room  living room     0       1
# 1      2022-04-24 00:01:30+00:00  living room  living room     0       1
# 2      2022-04-24 00:02:00+00:00  living room  living room     0       2
# 3      2022-04-24 00:02:30+00:00  living room  living room     0       2
# 4      2022-04-24 00:03:00+00:00  living room  living room     0       3
# ...                          ...          ...          ...   ...     ...
# 172793 2022-06-22 23:57:30+00:00      bedroom      bedroom    23      57
# 172794 2022-06-22 23:58:00+00:00      bedroom      bedroom    23      58
# 172795 2022-06-22 23:58:30+00:00      bedroom      bedroom    23      58
# 172796 2022-06-22 23:59:00+00:00      bedroom      bedroom    23      59
# 172797 2022-06-22 23:59:30+00:00      bedroom      bedroom    23      59
#
#         day_of_week  is_weekend
# 0                 6           1
# 1                 6           1
# 2                 6           1
# 3                 6           1
# 4                 6           1
# ...             ...         ...
# 172793            2           0
# 172794            2           0
# 172795            2           0
# 172796            2           0
# 172797            2           0
#
# [172798 rows x 7 columns]

# %% [markdown]
# ## Model Preprocessing

# %%
# Label-encode states
le_state_user1 = LabelEncoder()
le_state_user2 = LabelEncoder()

merged_df["state_user1"] = le_state_user1.fit_transform(merged_df["state_user1"])
merged_df["state_user2"] = le_state_user2.fit_transform(merged_df["state_user2"])

# Save encoders for later
with open("le_state_user1.pkl","wb") as f:
    pickle.dump(le_state_user1, f)
with open("le_state_user2.pkl","wb") as f:
    pickle.dump(le_state_user2, f)

# %%
# Cyclical features
merged_df["hour_sin"] = np.sin(2*np.pi*merged_df["hour"]/24)
merged_df["hour_cos"] = np.cos(2*np.pi*merged_df["hour"]/24)

merged_df["minute_sin"] = np.sin(2*np.pi*merged_df["minute"]/60)
merged_df["minute_cos"] = np.cos(2*np.pi*merged_df["minute"]/60)

merged_df["day_sin"] = np.sin(2*np.pi*merged_df["day_of_week"]/7)
merged_df["day_cos"] = np.cos(2*np.pi*merged_df["day_of_week"]/7)

# %%
# Drop columns not needed
merged_df.drop(columns=["time","hour","minute","day_of_week"], inplace=True)

# %%
merged_df
# Out:
#         state_user1  state_user2  is_weekend  hour_sin  hour_cos  minute_sin  \
# 0                 3            3           1  0.000000  1.000000    0.104528
# 1                 3            3           1  0.000000  1.000000    0.104528
# 2                 3            3           1  0.000000  1.000000    0.207912
# 3                 3            3           1  0.000000  1.000000    0.207912
# 4                 3            3           1  0.000000  1.000000    0.309017
# ...             ...          ...         ...       ...       ...         ...
# 172793            0            0           0 -0.258819  0.965926   -0.309017
# 172794            0            0           0 -0.258819  0.965926   -0.207912
# 172795            0            0           0 -0.258819  0.965926   -0.207912
# 172796            0            0           0 -0.258819  0.965926   -0.104528
# 172797            0            0           0 -0.258819  0.965926   -0.104528
#
#         minute_cos   day_sin   day_cos
# 0         0.994522 -0.781831  0.623490
# 1         0.994522 -0.781831  0.623490
# 2         0.978148 -0.781831  0.623490
# 3         0.978148 -0.781831  0.623490
# 4         0.951057 -0.781831  0.623490
# ...            ...       ...       ...
# 172793    0.951057  0.974928 -0.222521
# 172794    0.978148  0.974928 -0.222521
# 172795    0.978148  0.974928 -0.222521
# 172796    0.994522  0.974928 -0.222521
# 172797    0.994522  0.974928 -0.222521
#
# [172798 rows x 9 columns]

# %% [markdown]
# # Reshaping

# %%
num_states_user1 = len(le_state_user1.classes_)
num_states_user2 = len(le_state_user2.classes_)

# %%
# Suppose 24hr -> 30s intervals => 24*60*2 = 2880 time steps
time_steps = 2880

# Separate features vs states
features = merged_df.drop(columns=["state_user1","state_user2"]).values
user1_states = merged_df["state_user1"].values
user2_states = merged_df["state_user2"].values

# Keep only multiples of time_steps
num_samples = (len(features)//time_steps)*time_steps
features = features[:num_samples]
user1_states = user1_states[:num_samples]
user2_states = user2_states[:num_samples]

batch_size = num_samples//time_steps

# %%
# Reshape to (batch_size, time_steps, num_features)
X = features.reshape(batch_size, time_steps, features.shape[1])
y1 = user1_states.reshape(batch_size, time_steps, 1)
y2 = user2_states.reshape(batch_size, time_steps, 1)

# %%
print("X.shape =", X.shape, "y1.shape =", y1.shape, "y2.shape =", y2.shape)
# Out:
# X.shape = (59, 2880, 7) y1.shape = (59, 2880, 1) y2.shape = (59, 2880, 1)

# %% [markdown]
# # Building the LSTM Model

# %%
def create_lstm_model(input_shape, num_states_user1, num_states_user2):
    inputs = Input(shape=input_shape)

    x = LSTM(64, return_sequences=True, kernel_regularizer=l2(0.001))(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)

    x = LSTM(32, return_sequences=True, kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)

    # Output for user1
    out_user1 = Dense(num_states_user1, activation="softmax", name="state_user1")(x)
    # Output for user2
    out_user2 = Dense(num_states_user2, activation="softmax", name="state_user2")(x)

    model = Model(inputs=inputs, outputs=[out_user1, out_user2])

    # Provide a separate metric for each output
    model.compile(
        loss=["sparse_categorical_crossentropy","sparse_categorical_crossentropy"],
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        metrics=[["accuracy"], ["accuracy"]]
    )
    return model

# %%
num_states_user1 = len(le_state_user1.classes_)
num_states_user2 = len(le_state_user2.classes_)

# %% [markdown]
# # Model Training

# %%
tscv = TimeSeriesSplit(n_splits=5)

user1_reports = []
user2_reports = []

fold = 1
for train_idx, val_idx in tscv.split(X):
    print(f"\n===== FOLD {fold} / 5 =====\n")

    X_train, X_val = X[train_idx], X[val_idx]
    y1_train, y1_val = y1[train_idx], y1[val_idx]
    y2_train, y2_val = y2[train_idx], y2[val_idx]

    # Build fresh model
    model = create_lstm_model(
        input_shape=(X_train.shape[1], X_train.shape[2]),
        num_states_user1=num_states_user1,
        num_states_user2=num_states_user2
    )

    early_stop = tf.keras.callbacks.EarlyStopping(
        monitor="val_loss", 
        patience=3, 
        restore_best_weights=True
    )

    # Train
    model.fit(
        X_train, 
        {"state_user1": y1_train, "state_user2": y2_train},
        validation_data=(X_val, {"state_user1": y1_val, "state_user2": y2_val}),
        epochs=100,
        batch_size=4,
        callbacks=[early_stop]
    )

    # Evaluate on val
    y1_pred_probs, y2_pred_probs = model.predict(X_val)
    y1_pred = y1_pred_probs.argmax(axis=-1).flatten()
    y2_pred = y2_pred_probs.argmax(axis=-1).flatten()

    y1_val_flat = y1_val.flatten()
    y2_val_flat = y2_val.flatten()

    # Classification reports
    report_user1 = classification_report(y1_val_flat, y1_pred, output_dict=True)
    report_user2 = classification_report(y2_val_flat, y2_pred, output_dict=True)

    user1_reports.append(report_user1)
    user2_reports.append(report_user2)

    print("User1 Classification Report (Fold", fold, "):")
    print(classification_report(y1_val_flat, y1_pred))
    print("\nUser2 Classification Report (Fold", fold, "):")
    print(classification_report(y2_val_flat, y2_pred))

    fold += 1
# Out:
# ===== FOLD 1 / 5 =====
#
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 6.0435 - state_user1_accuracy: 0.0959 - state_user1_loss: 2.8302 - state_user2_accuracy: 0.1073 - state_user2_loss: 3.0935 - val_loss: 3.9352 - val_state_user1_accuracy: 0.2173 - val_state_user1_loss: 1.9106 - val_state_user2_accuracy: 0.2155 - val_state_user2_loss: 1.9445
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 4.9849 - state_user1_accuracy: 0.1758 - state_user1_loss: 2.3189 - state_user2_accuracy: 0.1702 - state_user2_loss: 2.5456 - val_loss: 3.8692 - val_state_user1_accuracy: 0.3149 - val_state_user1_loss: 1.8839 - val_state_user2_accuracy: 0.3218 - val_state_user2_loss: 1.8977
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 4.5173 - state_user1_accuracy: 0.1782 - state_user1_loss: 2.2278 - state_user2_accuracy: 0.2553 - state_user2_loss: 2.1709 - val_loss: 3.8045 - val_state_user1_accuracy: 0.3552 - val_state_user1_loss: 1.8606 - val_state_user2_accuracy: 0.4483 - val_state_user2_loss: 1.8495
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 4.0565 - state_user1_accuracy: 0.2419 - state_user1_loss: 2.0681 - state_user2_accuracy: 0.3519 - state_user2_loss: 1.8964 - val_loss: 3.7369 - val_state_user1_accuracy: 0.4277 - val_state_user1_loss: 1.8363 - val_state_user2_accuracy: 0.5137 - val_state_user2_loss: 1.7997
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 3.7223 - state_user1_accuracy: 0.3090 - state_user1_loss: 1.8768 - state_user2_accuracy: 0.4196 - state_user2_loss: 1.7350 - val_loss: 3.6727 - val_state_user1_accuracy: 0.4777 - val_state_user1_loss: 1.8113 - val_state_user2_accuracy: 0.5547 - val_state_user2_loss: 1.7526
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - loss: 3.5433 - state_user1_accuracy: 0.3549 - state_user1_loss: 1.8226 - state_user2_accuracy: 0.4708 - state_user2_loss: 1.6141 - val_loss: 3.6140 - val_state_user1_accuracy: 0.5054 - val_state_user1_loss: 1.7873 - val_state_user2_accuracy: 0.5797 - val_state_user2_loss: 1.7069
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - loss: 3.4552 - state_user1_accuracy: 0.3970 - state_user1_loss: 1.7376 - state_user2_accuracy: 0.5020 - state_user2_loss: 1.6077 - val_loss: 3.5600 - val_state_user1_accuracy: 0.5165 - val_state_user1_loss: 1.7660 - val_state_user2_accuracy: 0.6007 - val_state_user2_loss: 1.6638
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - loss: 3.3402 - state_user1_accuracy: 0.4256 - state_user1_loss: 1.6814 - state_user2_accuracy: 0.5224 - state_user2_loss: 1.5601 - val_loss: 3.5156 - val_state_user1_accuracy: 0.5179 - val_state_user1_loss: 1.7461 - val_state_user2_accuracy: 0.6115 - val_state_user2_loss: 1.6278
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - loss: 3.1001 - state_user1_accuracy: 0.4666 - state_user1_loss: 1.5699 - state_user2_accuracy: 0.5718 - state_user2_loss: 1.4405 - val_loss: 3.4737 - val_state_user1_accuracy: 0.5210 - val_state_user1_loss: 1.7233 - val_state_user2_accuracy: 0.6181 - val_state_user2_loss: 1.5983
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - loss: 3.0512 - state_user1_accuracy: 0.4867 - state_user1_loss: 1.5241 - state_user2_accuracy: 0.5850 - state_user2_loss: 1.4092 - val_loss: 3.4295 - val_state_user1_accuracy: 0.5225 - val_state_user1_loss: 1.7001 - val_state_user2_accuracy: 0.6209 - val_state_user2_loss: 1.5688
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - loss: 3.0674 - state_user1_accuracy: 0.4989 - state_user1_loss: 1.5264 - state_user2_accuracy: 0.5826 - state_user2_loss: 1.4192 - val_loss: 3.3780 - val_state_user1_accuracy: 0.5251 - val_state_user1_loss: 1.6721 - val_state_user2_accuracy: 0.6282 - val_state_user2_loss: 1.5397
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - loss: 2.9368 - state_user1_accuracy: 0.5324 - state_user1_loss: 1.4263 - state_user2_accuracy: 0.5991 - state_user2_loss: 1.3952 - val_loss: 3.3379 - val_state_user1_accuracy: 0.5338 - val_state_user1_loss: 1.6427 - val_state_user2_accuracy: 0.6324 - val_state_user2_loss: 1.5192
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 2.7842 - state_user1_accuracy: 0.5328 - state_user1_loss: 1.4566 - state_user2_accuracy: 0.6596 - state_user2_loss: 1.2356 - val_loss: 3.3052 - val_state_user1_accuracy: 0.5396 - val_state_user1_loss: 1.6123 - val_state_user2_accuracy: 0.6341 - val_state_user2_loss: 1.5058
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 2.7794 - state_user1_accuracy: 0.5804 - state_user1_loss: 1.3349 - state_user2_accuracy: 0.6229 - state_user2_loss: 1.3472 - val_loss: 3.2829 - val_state_user1_accuracy: 0.5480 - val_state_user1_loss: 1.5835 - val_state_user2_accuracy: 0.6295 - val_state_user2_loss: 1.5008
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 2.7316 - state_user1_accuracy: 0.5865 - state_user1_loss: 1.3282 - state_user2_accuracy: 0.6293 - state_user2_loss: 1.3101 - val_loss: 3.2466 - val_state_user1_accuracy: 0.5638 - val_state_user1_loss: 1.5571 - val_state_user2_accuracy: 0.6269 - val_state_user2_loss: 1.4848
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 2.6013 - state_user1_accuracy: 0.5951 - state_user1_loss: 1.3393 - state_user2_accuracy: 0.6789 - state_user2_loss: 1.1792 - val_loss: 3.2223 - val_state_user1_accuracy: 0.5762 - val_state_user1_loss: 1.5381 - val_state_user2_accuracy: 0.6260 - val_state_user2_loss: 1.4726
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 2.6235 - state_user1_accuracy: 0.6010 - state_user1_loss: 1.2988 - state_user2_accuracy: 0.6690 - state_user2_loss: 1.2526 - val_loss: 3.1734 - val_state_user1_accuracy: 0.5977 - val_state_user1_loss: 1.5086 - val_state_user2_accuracy: 0.6305 - val_state_user2_loss: 1.4543
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 2.6929 - state_user1_accuracy: 0.6146 - state_user1_loss: 1.2703 - state_user2_accuracy: 0.6325 - state_user2_loss: 1.3111 - val_loss: 3.1415 - val_state_user1_accuracy: 0.6053 - val_state_user1_loss: 1.4827 - val_state_user2_accuracy: 0.6313 - val_state_user2_loss: 1.4461
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 2.4590 - state_user1_accuracy: 0.6563 - state_user1_loss: 1.2103 - state_user2_accuracy: 0.6682 - state_user2_loss: 1.2039 - val_loss: 3.1379 - val_state_user1_accuracy: 0.6093 - val_state_user1_loss: 1.4648 - val_state_user2_accuracy: 0.6284 - val_state_user2_loss: 1.4500
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 2.6244 - state_user1_accuracy: 0.6435 - state_user1_loss: 1.1913 - state_user2_accuracy: 0.6261 - state_user2_loss: 1.3249 - val_loss: 3.1483 - val_state_user1_accuracy: 0.6033 - val_state_user1_loss: 1.4586 - val_state_user2_accuracy: 0.6201 - val_state_user2_loss: 1.4563
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 2.4628 - state_user1_accuracy: 0.6249 - state_user1_loss: 1.2469 - state_user2_accuracy: 0.6955 - state_user2_loss: 1.1073 - val_loss: 3.1265 - val_state_user1_accuracy: 0.6000 - val_state_user1_loss: 1.4491 - val_state_user2_accuracy: 0.6220 - val_state_user2_loss: 1.4435
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 2.4760 - state_user1_accuracy: 0.6425 - state_user1_loss: 1.2160 - state_user2_accuracy: 0.6797 - state_user2_loss: 1.1436 - val_loss: 3.1319 - val_state_user1_accuracy: 0.5936 - val_state_user1_loss: 1.4463 - val_state_user2_accuracy: 0.6126 - val_state_user2_loss: 1.4428
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 2.4725 - state_user1_accuracy: 0.6286 - state_user1_loss: 1.2174 - state_user2_accuracy: 0.6809 - state_user2_loss: 1.1831 - val_loss: 3.1205 - val_state_user1_accuracy: 0.6000 - val_state_user1_loss: 1.4408 - val_state_user2_accuracy: 0.6137 - val_state_user2_loss: 1.4348
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - loss: 2.3623 - state_user1_accuracy: 0.6611 - state_user1_loss: 1.1357 - state_user2_accuracy: 0.7025 - state_user2_loss: 1.1183 - val_loss: 3.0631 - val_state_user1_accuracy: 0.6107 - val_state_user1_loss: 1.3954 - val_state_user2_accuracy: 0.6202 - val_state_user2_loss: 1.4186
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 2.4198 - state_user1_accuracy: 0.6347 - state_user1_loss: 1.2359 - state_user2_accuracy: 0.7172 - state_user2_loss: 1.1072 - val_loss: 3.0193 - val_state_user1_accuracy: 0.6222 - val_state_user1_loss: 1.3647 - val_state_user2_accuracy: 0.6249 - val_state_user2_loss: 1.4081
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 2.4448 - state_user1_accuracy: 0.6775 - state_user1_loss: 1.0854 - state_user2_accuracy: 0.6520 - state_user2_loss: 1.2487 - val_loss: 3.0131 - val_state_user1_accuracy: 0.6211 - val_state_user1_loss: 1.3612 - val_state_user2_accuracy: 0.6273 - val_state_user2_loss: 1.4063
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 2.5079 - state_user1_accuracy: 0.6375 - state_user1_loss: 1.1998 - state_user2_accuracy: 0.6741 - state_user2_loss: 1.2032 - val_loss: 2.9976 - val_state_user1_accuracy: 0.6214 - val_state_user1_loss: 1.3434 - val_state_user2_accuracy: 0.6225 - val_state_user2_loss: 1.4044
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 2.3145 - state_user1_accuracy: 0.6719 - state_user1_loss: 1.0762 - state_user2_accuracy: 0.6921 - state_user2_loss: 1.1682 - val_loss: 3.0082 - val_state_user1_accuracy: 0.6164 - val_state_user1_loss: 1.3424 - val_state_user2_accuracy: 0.6146 - val_state_user2_loss: 1.4088
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 2.3349 - state_user1_accuracy: 0.6904 - state_user1_loss: 1.0442 - state_user2_accuracy: 0.6686 - state_user2_loss: 1.2089 - val_loss: 3.0132 - val_state_user1_accuracy: 0.6098 - val_state_user1_loss: 1.3442 - val_state_user2_accuracy: 0.6161 - val_state_user2_loss: 1.4077
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 2.4163 - state_user1_accuracy: 0.6813 - state_user1_loss: 1.0488 - state_user2_accuracy: 0.6497 - state_user2_loss: 1.2895 - val_loss: 3.0168 - val_state_user1_accuracy: 0.6119 - val_state_user1_loss: 1.3413 - val_state_user2_accuracy: 0.6201 - val_state_user2_loss: 1.4067
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# User1 Classification Report (Fold 1 ):
#               precision    recall  f1-score   support
#
#            0       0.52      0.83      0.64      6088
#            1       0.00      0.00      0.00       184
#            2       0.00      0.00      0.00      1086
#            3       0.16      0.11      0.13      1853
#            4       0.00      0.00      0.00       483
#            5       0.73      0.76      0.75     14166
#            6       0.00      0.00      0.00      2060
#
#     accuracy                           0.62     25920
#    macro avg       0.20      0.24      0.22     25920
# weighted avg       0.53      0.62      0.57     25920
#
#
# User2 Classification Report (Fold 1 ):
#               precision    recall  f1-score   support
#
#            0       0.58      0.75      0.66      9334
#            1       0.00      0.00      0.00       384
#            2       0.00      0.00      0.00       721
#            3       0.00      0.00      0.00      1008
#            4       0.00      0.00      0.00         8
#            5       0.67      0.68      0.67     13353
#            6       0.00      0.00      0.00      1112
#
#     accuracy                           0.62     25920
#    macro avg       0.18      0.21      0.19     25920
# weighted avg       0.55      0.62      0.58     25920
#
#
# ===== FOLD 2 / 5 =====
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 5.6898 - state_user1_accuracy: 0.1442 - state_user1_loss: 2.9666 - state_user2_accuracy: 0.1525 - state_user2_loss: 2.6152 - val_loss: 3.9248 - val_state_user1_accuracy: 0.2311 - val_state_user1_loss: 1.9471 - val_state_user2_accuracy: 0.3223 - val_state_user2_loss: 1.8972
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 4.4584 - state_user1_accuracy: 0.2381 - state_user1_loss: 2.2293 - state_user2_accuracy: 0.2809 - state_user2_loss: 2.1274 - val_loss: 3.8149 - val_state_user1_accuracy: 0.4579 - val_state_user1_loss: 1.8727 - val_state_user2_accuracy: 0.4303 - val_state_user2_loss: 1.8471
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 3.9771 - state_user1_accuracy: 0.3361 - state_user1_loss: 1.9798 - state_user2_accuracy: 0.3805 - state_user2_loss: 1.9004 - val_loss: 3.7122 - val_state_user1_accuracy: 0.5436 - val_state_user1_loss: 1.8026 - val_state_user2_accuracy: 0.4708 - val_state_user2_loss: 1.8016
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 3.6724 - state_user1_accuracy: 0.4109 - state_user1_loss: 1.8009 - state_user2_accuracy: 0.4311 - state_user2_loss: 1.7757 - val_loss: 3.6234 - val_state_user1_accuracy: 0.5732 - val_state_user1_loss: 1.7355 - val_state_user2_accuracy: 0.5000 - val_state_user2_loss: 1.7700
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 3.4546 - state_user1_accuracy: 0.4419 - state_user1_loss: 1.7747 - state_user2_accuracy: 0.5013 - state_user2_loss: 1.5859 - val_loss: 3.5448 - val_state_user1_accuracy: 0.5862 - val_state_user1_loss: 1.6838 - val_state_user2_accuracy: 0.5433 - val_state_user2_loss: 1.7358
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 3.2826 - state_user1_accuracy: 0.4844 - state_user1_loss: 1.6129 - state_user2_accuracy: 0.5307 - state_user2_loss: 1.5778 - val_loss: 3.4680 - val_state_user1_accuracy: 0.6090 - val_state_user1_loss: 1.6422 - val_state_user2_accuracy: 0.5797 - val_state_user2_loss: 1.6985
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 3.3262 - state_user1_accuracy: 0.4964 - state_user1_loss: 1.5533 - state_user2_accuracy: 0.5315 - state_user2_loss: 1.6726 - val_loss: 3.3972 - val_state_user1_accuracy: 0.6307 - val_state_user1_loss: 1.5994 - val_state_user2_accuracy: 0.5979 - val_state_user2_loss: 1.6664
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 3.2312 - state_user1_accuracy: 0.5032 - state_user1_loss: 1.6160 - state_user2_accuracy: 0.5764 - state_user2_loss: 1.5165 - val_loss: 3.3170 - val_state_user1_accuracy: 0.6411 - val_state_user1_loss: 1.5460 - val_state_user2_accuracy: 0.6038 - val_state_user2_loss: 1.6258
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 3.2975 - state_user1_accuracy: 0.4964 - state_user1_loss: 1.5926 - state_user2_accuracy: 0.5807 - state_user2_loss: 1.6046 - val_loss: 3.2518 - val_state_user1_accuracy: 0.6495 - val_state_user1_loss: 1.5020 - val_state_user2_accuracy: 0.6046 - val_state_user2_loss: 1.6002
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.9167 - state_user1_accuracy: 0.5627 - state_user1_loss: 1.4128 - state_user2_accuracy: 0.6170 - state_user2_loss: 1.4061 - val_loss: 3.1926 - val_state_user1_accuracy: 0.6534 - val_state_user1_loss: 1.4618 - val_state_user2_accuracy: 0.6026 - val_state_user2_loss: 1.5774
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.7909 - state_user1_accuracy: 0.6103 - state_user1_loss: 1.2909 - state_user2_accuracy: 0.6174 - state_user2_loss: 1.4123 - val_loss: 3.1300 - val_state_user1_accuracy: 0.6524 - val_state_user1_loss: 1.4112 - val_state_user2_accuracy: 0.6035 - val_state_user2_loss: 1.5623
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.8930 - state_user1_accuracy: 0.5742 - state_user1_loss: 1.3709 - state_user2_accuracy: 0.6147 - state_user2_loss: 1.4218 - val_loss: 3.0763 - val_state_user1_accuracy: 0.6573 - val_state_user1_loss: 1.3759 - val_state_user2_accuracy: 0.6064 - val_state_user2_loss: 1.5441
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - loss: 2.8097 - state_user1_accuracy: 0.6170 - state_user1_loss: 1.2441 - state_user2_accuracy: 0.5894 - state_user2_loss: 1.4712 - val_loss: 3.0161 - val_state_user1_accuracy: 0.6621 - val_state_user1_loss: 1.3422 - val_state_user2_accuracy: 0.6069 - val_state_user2_loss: 1.5166
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - loss: 2.7943 - state_user1_accuracy: 0.6316 - state_user1_loss: 1.1918 - state_user2_accuracy: 0.5695 - state_user2_loss: 1.5039 - val_loss: 2.9655 - val_state_user1_accuracy: 0.6587 - val_state_user1_loss: 1.3057 - val_state_user2_accuracy: 0.6101 - val_state_user2_loss: 1.4937
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.7784 - state_user1_accuracy: 0.5814 - state_user1_loss: 1.2839 - state_user2_accuracy: 0.6061 - state_user2_loss: 1.3922 - val_loss: 2.9168 - val_state_user1_accuracy: 0.6553 - val_state_user1_loss: 1.2692 - val_state_user2_accuracy: 0.6080 - val_state_user2_loss: 1.4688
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.6692 - state_user1_accuracy: 0.6287 - state_user1_loss: 1.1585 - state_user2_accuracy: 0.6018 - state_user2_loss: 1.4143 - val_loss: 2.8962 - val_state_user1_accuracy: 0.6359 - val_state_user1_loss: 1.2426 - val_state_user2_accuracy: 0.5983 - val_state_user2_loss: 1.4584
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.5735 - state_user1_accuracy: 0.6197 - state_user1_loss: 1.1884 - state_user2_accuracy: 0.6364 - state_user2_loss: 1.2858 - val_loss: 2.8670 - val_state_user1_accuracy: 0.6505 - val_state_user1_loss: 1.2258 - val_state_user2_accuracy: 0.5964 - val_state_user2_loss: 1.4530
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.5695 - state_user1_accuracy: 0.6288 - state_user1_loss: 1.1434 - state_user2_accuracy: 0.6258 - state_user2_loss: 1.3291 - val_loss: 2.8307 - val_state_user1_accuracy: 0.6587 - val_state_user1_loss: 1.2069 - val_state_user2_accuracy: 0.5935 - val_state_user2_loss: 1.4445
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.6132 - state_user1_accuracy: 0.6240 - state_user1_loss: 1.1817 - state_user2_accuracy: 0.6365 - state_user2_loss: 1.3399 - val_loss: 2.7906 - val_state_user1_accuracy: 0.6609 - val_state_user1_loss: 1.1731 - val_state_user2_accuracy: 0.5970 - val_state_user2_loss: 1.4300
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.4581 - state_user1_accuracy: 0.6388 - state_user1_loss: 1.1307 - state_user2_accuracy: 0.6615 - state_user2_loss: 1.2329 - val_loss: 2.7788 - val_state_user1_accuracy: 0.6517 - val_state_user1_loss: 1.1604 - val_state_user2_accuracy: 0.5941 - val_state_user2_loss: 1.4234
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.3923 - state_user1_accuracy: 0.6348 - state_user1_loss: 1.1232 - state_user2_accuracy: 0.6653 - state_user2_loss: 1.1790 - val_loss: 2.7508 - val_state_user1_accuracy: 0.6526 - val_state_user1_loss: 1.1462 - val_state_user2_accuracy: 0.5956 - val_state_user2_loss: 1.4091
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.4551 - state_user1_accuracy: 0.6181 - state_user1_loss: 1.1570 - state_user2_accuracy: 0.6670 - state_user2_loss: 1.2045 - val_loss: 2.7158 - val_state_user1_accuracy: 0.6671 - val_state_user1_loss: 1.1252 - val_state_user2_accuracy: 0.5926 - val_state_user2_loss: 1.4022
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.6075 - state_user1_accuracy: 0.6232 - state_user1_loss: 1.1321 - state_user2_accuracy: 0.5931 - state_user2_loss: 1.3818 - val_loss: 2.6889 - val_state_user1_accuracy: 0.6690 - val_state_user1_loss: 1.0930 - val_state_user2_accuracy: 0.5806 - val_state_user2_loss: 1.3976
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.3526 - state_user1_accuracy: 0.6475 - state_user1_loss: 1.0954 - state_user2_accuracy: 0.6790 - state_user2_loss: 1.1599 - val_loss: 2.6629 - val_state_user1_accuracy: 0.6986 - val_state_user1_loss: 1.0769 - val_state_user2_accuracy: 0.5907 - val_state_user2_loss: 1.3812
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.4518 - state_user1_accuracy: 0.6349 - state_user1_loss: 1.1360 - state_user2_accuracy: 0.6566 - state_user2_loss: 1.2223 - val_loss: 2.6694 - val_state_user1_accuracy: 0.6848 - val_state_user1_loss: 1.0769 - val_state_user2_accuracy: 0.5782 - val_state_user2_loss: 1.3864
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.3384 - state_user1_accuracy: 0.6624 - state_user1_loss: 1.0194 - state_user2_accuracy: 0.6486 - state_user2_loss: 1.2209 - val_loss: 2.6445 - val_state_user1_accuracy: 0.6714 - val_state_user1_loss: 1.0434 - val_state_user2_accuracy: 0.5750 - val_state_user2_loss: 1.3912
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.4255 - state_user1_accuracy: 0.6608 - state_user1_loss: 1.0450 - state_user2_accuracy: 0.6342 - state_user2_loss: 1.2889 - val_loss: 2.6327 - val_state_user1_accuracy: 0.6665 - val_state_user1_loss: 1.0298 - val_state_user2_accuracy: 0.5854 - val_state_user2_loss: 1.3816
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.4542 - state_user1_accuracy: 0.6490 - state_user1_loss: 1.0726 - state_user2_accuracy: 0.6339 - state_user2_loss: 1.2869 - val_loss: 2.6190 - val_state_user1_accuracy: 0.6716 - val_state_user1_loss: 1.0147 - val_state_user2_accuracy: 0.5782 - val_state_user2_loss: 1.3790
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.3088 - state_user1_accuracy: 0.6454 - state_user1_loss: 1.0552 - state_user2_accuracy: 0.6672 - state_user2_loss: 1.1625 - val_loss: 2.6167 - val_state_user1_accuracy: 0.6852 - val_state_user1_loss: 1.0174 - val_state_user2_accuracy: 0.5686 - val_state_user2_loss: 1.3824
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.3092 - state_user1_accuracy: 0.6628 - state_user1_loss: 1.0151 - state_user2_accuracy: 0.6434 - state_user2_loss: 1.2042 - val_loss: 2.6530 - val_state_user1_accuracy: 0.6644 - val_state_user1_loss: 1.0322 - val_state_user2_accuracy: 0.5692 - val_state_user2_loss: 1.3867
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.3117 - state_user1_accuracy: 0.6596 - state_user1_loss: 1.0241 - state_user2_accuracy: 0.6369 - state_user2_loss: 1.1987 - val_loss: 2.5982 - val_state_user1_accuracy: 0.6799 - val_state_user1_loss: 1.0019 - val_state_user2_accuracy: 0.5677 - val_state_user2_loss: 1.3720
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.2199 - state_user1_accuracy: 0.6527 - state_user1_loss: 1.0344 - state_user2_accuracy: 0.6746 - state_user2_loss: 1.0962 - val_loss: 2.6166 - val_state_user1_accuracy: 0.6792 - val_state_user1_loss: 1.0011 - val_state_user2_accuracy: 0.5659 - val_state_user2_loss: 1.3884
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.2981 - state_user1_accuracy: 0.6299 - state_user1_loss: 1.0592 - state_user2_accuracy: 0.6586 - state_user2_loss: 1.1496 - val_loss: 2.6319 - val_state_user1_accuracy: 0.6865 - val_state_user1_loss: 0.9621 - val_state_user2_accuracy: 0.5848 - val_state_user2_loss: 1.4114
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.3597 - state_user1_accuracy: 0.6652 - state_user1_loss: 1.0448 - state_user2_accuracy: 0.6409 - state_user2_loss: 1.2260 - val_loss: 2.5805 - val_state_user1_accuracy: 0.6659 - val_state_user1_loss: 0.9828 - val_state_user2_accuracy: 0.5699 - val_state_user2_loss: 1.3658
# Epoch 35/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.3372 - state_user1_accuracy: 0.6519 - state_user1_loss: 1.0423 - state_user2_accuracy: 0.6587 - state_user2_loss: 1.2052 - val_loss: 2.5720 - val_state_user1_accuracy: 0.7048 - val_state_user1_loss: 0.9691 - val_state_user2_accuracy: 0.5852 - val_state_user2_loss: 1.3711
# Epoch 36/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.2696 - state_user1_accuracy: 0.6453 - state_user1_loss: 1.0380 - state_user2_accuracy: 0.6540 - state_user2_loss: 1.1434 - val_loss: 2.6006 - val_state_user1_accuracy: 0.6973 - val_state_user1_loss: 0.9763 - val_state_user2_accuracy: 0.5857 - val_state_user2_loss: 1.3789
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.3532 - state_user1_accuracy: 0.6466 - state_user1_loss: 1.0576 - state_user2_accuracy: 0.6521 - state_user2_loss: 1.2045 - val_loss: 2.5619 - val_state_user1_accuracy: 0.6953 - val_state_user1_loss: 0.9528 - val_state_user2_accuracy: 0.5912 - val_state_user2_loss: 1.3567
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.1215 - state_user1_accuracy: 0.6775 - state_user1_loss: 0.9810 - state_user2_accuracy: 0.6968 - state_user2_loss: 1.0581 - val_loss: 2.6001 - val_state_user1_accuracy: 0.6825 - val_state_user1_loss: 0.9647 - val_state_user2_accuracy: 0.5613 - val_state_user2_loss: 1.3922
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.2883 - state_user1_accuracy: 0.6616 - state_user1_loss: 0.9814 - state_user2_accuracy: 0.6198 - state_user2_loss: 1.2167 - val_loss: 2.5882 - val_state_user1_accuracy: 0.6785 - val_state_user1_loss: 0.9588 - val_state_user2_accuracy: 0.5582 - val_state_user2_loss: 1.3908
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.0826 - state_user1_accuracy: 0.6558 - state_user1_loss: 0.9997 - state_user2_accuracy: 0.6890 - state_user2_loss: 1.0043 - val_loss: 2.6237 - val_state_user1_accuracy: 0.6801 - val_state_user1_loss: 0.9405 - val_state_user2_accuracy: 0.5548 - val_state_user2_loss: 1.4261
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step
# User1 Classification Report (Fold 2 ):
#               precision    recall  f1-score   support
#
#            0       0.82      0.79      0.80      8806
#            1       0.00      0.00      0.00       183
#            2       0.00      0.00      0.00      1365
#            3       0.34      0.06      0.10      2419
#            4       0.00      0.00      0.00       433
#            5       0.64      0.99      0.78     10915
#            6       0.53      0.06      0.10      1799
#
#     accuracy                           0.70     25920
#    macro avg       0.33      0.27      0.25     25920
# weighted avg       0.62      0.70      0.62     25920
#
#
# User2 Classification Report (Fold 2 ):
#               precision    recall  f1-score   support
#
#            0       0.63      0.70      0.66     10669
#            1       0.00      0.00      0.00       397
#            2       0.00      0.00      0.00       966
#            3       0.00      0.00      0.00      1158
#            4       0.00      0.00      0.00        10
#            5       0.56      0.68      0.62     11456
#            6       0.00      0.00      0.00      1264
#
#     accuracy                           0.59     25920
#    macro avg       0.17      0.20      0.18     25920
# weighted avg       0.51      0.59      0.55     25920
#
#
# ===== FOLD 3 / 5 =====
#
# Epoch 1/100
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 940ms/step - loss: 5.2567 - state_user1_accuracy: 0.1792 - state_user1_loss: 2.5614 - state_user2_accuracy: 0.1741 - state_user2_loss: 2.5957 - val_loss: 3.8520 - val_state_user1_accuracy: 0.3547 - val_state_user1_loss: 1.8641 - val_state_user2_accuracy: 0.3709 - val_state_user2_loss: 1.8811
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 887ms/step - loss: 4.1578 - state_user1_accuracy: 0.2966 - state_user1_loss: 1.9757 - state_user2_accuracy: 0.2980 - state_user2_loss: 2.0828 - val_loss: 3.7204 - val_state_user1_accuracy: 0.5140 - val_state_user1_loss: 1.7853 - val_state_user2_accuracy: 0.5022 - val_state_user2_loss: 1.8429
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 873ms/step - loss: 3.8347 - state_user1_accuracy: 0.4029 - state_user1_loss: 1.7324 - state_user2_accuracy: 0.3627 - state_user2_loss: 2.0034 - val_loss: 3.6143 - val_state_user1_accuracy: 0.5754 - val_state_user1_loss: 1.7278 - val_state_user2_accuracy: 0.5357 - val_state_user2_loss: 1.8077
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 878ms/step - loss: 3.7066 - state_user1_accuracy: 0.4344 - state_user1_loss: 1.6909 - state_user2_accuracy: 0.4111 - state_user2_loss: 1.9172 - val_loss: 3.5154 - val_state_user1_accuracy: 0.6225 - val_state_user1_loss: 1.6667 - val_state_user2_accuracy: 0.5905 - val_state_user2_loss: 1.7821
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 909ms/step - loss: 3.3515 - state_user1_accuracy: 0.5040 - state_user1_loss: 1.5269 - state_user2_accuracy: 0.4839 - state_user2_loss: 1.7266 - val_loss: 3.4109 - val_state_user1_accuracy: 0.6405 - val_state_user1_loss: 1.6082 - val_state_user2_accuracy: 0.6073 - val_state_user2_loss: 1.7499
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 907ms/step - loss: 2.9263 - state_user1_accuracy: 0.5553 - state_user1_loss: 1.3921 - state_user2_accuracy: 0.5752 - state_user2_loss: 1.4368 - val_loss: 3.2902 - val_state_user1_accuracy: 0.6442 - val_state_user1_loss: 1.5509 - val_state_user2_accuracy: 0.6182 - val_state_user2_loss: 1.6975
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 867ms/step - loss: 3.0997 - state_user1_accuracy: 0.5906 - state_user1_loss: 1.3072 - state_user2_accuracy: 0.5255 - state_user2_loss: 1.6956 - val_loss: 3.1947 - val_state_user1_accuracy: 0.6427 - val_state_user1_loss: 1.4820 - val_state_user2_accuracy: 0.6220 - val_state_user2_loss: 1.6710
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 892ms/step - loss: 2.8651 - state_user1_accuracy: 0.6198 - state_user1_loss: 1.2633 - state_user2_accuracy: 0.5754 - state_user2_loss: 1.5053 - val_loss: 3.0988 - val_state_user1_accuracy: 0.6630 - val_state_user1_loss: 1.4068 - val_state_user2_accuracy: 0.6196 - val_state_user2_loss: 1.6613
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 902ms/step - loss: 2.8407 - state_user1_accuracy: 0.6121 - state_user1_loss: 1.2443 - state_user2_accuracy: 0.5760 - state_user2_loss: 1.5004 - val_loss: 3.0137 - val_state_user1_accuracy: 0.6795 - val_state_user1_loss: 1.3455 - val_state_user2_accuracy: 0.6153 - val_state_user2_loss: 1.6495
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 916ms/step - loss: 2.8121 - state_user1_accuracy: 0.6369 - state_user1_loss: 1.1644 - state_user2_accuracy: 0.5553 - state_user2_loss: 1.5522 - val_loss: 2.9549 - val_state_user1_accuracy: 0.6782 - val_state_user1_loss: 1.3015 - val_state_user2_accuracy: 0.6171 - val_state_user2_loss: 1.6334
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 921ms/step - loss: 2.7851 - state_user1_accuracy: 0.6262 - state_user1_loss: 1.2075 - state_user2_accuracy: 0.5845 - state_user2_loss: 1.4827 - val_loss: 2.8785 - val_state_user1_accuracy: 0.6806 - val_state_user1_loss: 1.2511 - val_state_user2_accuracy: 0.6228 - val_state_user2_loss: 1.6082
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 889ms/step - loss: 3.0607 - state_user1_accuracy: 0.6230 - state_user1_loss: 1.3182 - state_user2_accuracy: 0.5704 - state_user2_loss: 1.6481 - val_loss: 2.7911 - val_state_user1_accuracy: 0.6800 - val_state_user1_loss: 1.2006 - val_state_user2_accuracy: 0.6269 - val_state_user2_loss: 1.5744
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 867ms/step - loss: 2.6275 - state_user1_accuracy: 0.6515 - state_user1_loss: 1.1276 - state_user2_accuracy: 0.6017 - state_user2_loss: 1.4059 - val_loss: 2.7762 - val_state_user1_accuracy: 0.6655 - val_state_user1_loss: 1.1684 - val_state_user2_accuracy: 0.6194 - val_state_user2_loss: 1.5874
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 907ms/step - loss: 2.7595 - state_user1_accuracy: 0.6401 - state_user1_loss: 1.1130 - state_user2_accuracy: 0.5795 - state_user2_loss: 1.5530 - val_loss: 2.7103 - val_state_user1_accuracy: 0.6753 - val_state_user1_loss: 1.1328 - val_state_user2_accuracy: 0.6204 - val_state_user2_loss: 1.5679
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 885ms/step - loss: 2.7068 - state_user1_accuracy: 0.6117 - state_user1_loss: 1.1833 - state_user2_accuracy: 0.6189 - state_user2_loss: 1.4306 - val_loss: 2.6942 - val_state_user1_accuracy: 0.6736 - val_state_user1_loss: 1.1345 - val_state_user2_accuracy: 0.6258 - val_state_user2_loss: 1.5488
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 867ms/step - loss: 2.6688 - state_user1_accuracy: 0.6524 - state_user1_loss: 1.0748 - state_user2_accuracy: 0.5901 - state_user2_loss: 1.5016 - val_loss: 2.6043 - val_state_user1_accuracy: 0.6769 - val_state_user1_loss: 1.0977 - val_state_user2_accuracy: 0.6316 - val_state_user2_loss: 1.5111
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 873ms/step - loss: 2.6421 - state_user1_accuracy: 0.6582 - state_user1_loss: 1.1073 - state_user2_accuracy: 0.6036 - state_user2_loss: 1.4429 - val_loss: 2.6112 - val_state_user1_accuracy: 0.6805 - val_state_user1_loss: 1.0449 - val_state_user2_accuracy: 0.6189 - val_state_user2_loss: 1.5703
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 893ms/step - loss: 2.5287 - state_user1_accuracy: 0.6495 - state_user1_loss: 1.0824 - state_user2_accuracy: 0.6202 - state_user2_loss: 1.3550 - val_loss: 2.5492 - val_state_user1_accuracy: 0.6885 - val_state_user1_loss: 1.0265 - val_state_user2_accuracy: 0.6240 - val_state_user2_loss: 1.5175
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 874ms/step - loss: 2.6295 - state_user1_accuracy: 0.6302 - state_user1_loss: 1.1016 - state_user2_accuracy: 0.6020 - state_user2_loss: 1.4369 - val_loss: 2.5076 - val_state_user1_accuracy: 0.6875 - val_state_user1_loss: 1.0139 - val_state_user2_accuracy: 0.6276 - val_state_user2_loss: 1.4865
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 886ms/step - loss: 2.4021 - state_user1_accuracy: 0.6892 - state_user1_loss: 0.9842 - state_user2_accuracy: 0.6173 - state_user2_loss: 1.3275 - val_loss: 2.4934 - val_state_user1_accuracy: 0.6822 - val_state_user1_loss: 0.9928 - val_state_user2_accuracy: 0.6231 - val_state_user2_loss: 1.5036
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 861ms/step - loss: 2.3723 - state_user1_accuracy: 0.6482 - state_user1_loss: 1.0286 - state_user2_accuracy: 0.6544 - state_user2_loss: 1.2538 - val_loss: 2.4590 - val_state_user1_accuracy: 0.6834 - val_state_user1_loss: 0.9737 - val_state_user2_accuracy: 0.6239 - val_state_user2_loss: 1.4882
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 881ms/step - loss: 2.3496 - state_user1_accuracy: 0.6679 - state_user1_loss: 1.0056 - state_user2_accuracy: 0.6429 - state_user2_loss: 1.2546 - val_loss: 2.4764 - val_state_user1_accuracy: 0.6718 - val_state_user1_loss: 0.9778 - val_state_user2_accuracy: 0.6208 - val_state_user2_loss: 1.4943
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 2.3989 - state_user1_accuracy: 0.6733 - state_user1_loss: 1.0251 - state_user2_accuracy: 0.6375 - state_user2_loss: 1.2849 - val_loss: 2.4612 - val_state_user1_accuracy: 0.6664 - val_state_user1_loss: 0.9584 - val_state_user2_accuracy: 0.6221 - val_state_user2_loss: 1.5097
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 2.3120 - state_user1_accuracy: 0.6686 - state_user1_loss: 1.0049 - state_user2_accuracy: 0.6488 - state_user2_loss: 1.2186 - val_loss: 2.4491 - val_state_user1_accuracy: 0.6700 - val_state_user1_loss: 0.9457 - val_state_user2_accuracy: 0.6216 - val_state_user2_loss: 1.5148
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 2.3962 - state_user1_accuracy: 0.6863 - state_user1_loss: 0.9843 - state_user2_accuracy: 0.6032 - state_user2_loss: 1.3239 - val_loss: 2.4201 - val_state_user1_accuracy: 0.6676 - val_state_user1_loss: 0.9347 - val_state_user2_accuracy: 0.6265 - val_state_user2_loss: 1.4964
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 2.3258 - state_user1_accuracy: 0.6728 - state_user1_loss: 1.0063 - state_user2_accuracy: 0.6542 - state_user2_loss: 1.2321 - val_loss: 2.4089 - val_state_user1_accuracy: 0.6648 - val_state_user1_loss: 0.9231 - val_state_user2_accuracy: 0.6277 - val_state_user2_loss: 1.5092
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 2.2964 - state_user1_accuracy: 0.6827 - state_user1_loss: 0.9519 - state_user2_accuracy: 0.6345 - state_user2_loss: 1.2575 - val_loss: 2.3857 - val_state_user1_accuracy: 0.6638 - val_state_user1_loss: 0.9102 - val_state_user2_accuracy: 0.6269 - val_state_user2_loss: 1.4997
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 2.2664 - state_user1_accuracy: 0.6666 - state_user1_loss: 1.0129 - state_user2_accuracy: 0.6671 - state_user2_loss: 1.1669 - val_loss: 2.3779 - val_state_user1_accuracy: 0.6638 - val_state_user1_loss: 0.8903 - val_state_user2_accuracy: 0.6176 - val_state_user2_loss: 1.5003
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 2.2704 - state_user1_accuracy: 0.6638 - state_user1_loss: 0.9906 - state_user2_accuracy: 0.6399 - state_user2_loss: 1.1937 - val_loss: 2.3452 - val_state_user1_accuracy: 0.6734 - val_state_user1_loss: 0.8824 - val_state_user2_accuracy: 0.6202 - val_state_user2_loss: 1.4830
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 2.3704 - state_user1_accuracy: 0.6741 - state_user1_loss: 0.9926 - state_user2_accuracy: 0.6104 - state_user2_loss: 1.2922 - val_loss: 2.3231 - val_state_user1_accuracy: 0.6676 - val_state_user1_loss: 0.8842 - val_state_user2_accuracy: 0.6241 - val_state_user2_loss: 1.4491
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 899ms/step - loss: 2.3044 - state_user1_accuracy: 0.6689 - state_user1_loss: 0.9803 - state_user2_accuracy: 0.6236 - state_user2_loss: 1.2389 - val_loss: 2.3630 - val_state_user1_accuracy: 0.6586 - val_state_user1_loss: 0.8895 - val_state_user2_accuracy: 0.6183 - val_state_user2_loss: 1.5010
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 915ms/step - loss: 2.2348 - state_user1_accuracy: 0.6778 - state_user1_loss: 0.9757 - state_user2_accuracy: 0.6496 - state_user2_loss: 1.1745 - val_loss: 2.3346 - val_state_user1_accuracy: 0.6620 - val_state_user1_loss: 0.8757 - val_state_user2_accuracy: 0.6204 - val_state_user2_loss: 1.4930
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 891ms/step - loss: 2.2958 - state_user1_accuracy: 0.6593 - state_user1_loss: 0.9966 - state_user2_accuracy: 0.6317 - state_user2_loss: 1.2150 - val_loss: 2.2814 - val_state_user1_accuracy: 0.6733 - val_state_user1_loss: 0.8470 - val_state_user2_accuracy: 0.6206 - val_state_user2_loss: 1.4738
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 892ms/step - loss: 2.2859 - state_user1_accuracy: 0.6453 - state_user1_loss: 1.0247 - state_user2_accuracy: 0.6395 - state_user2_loss: 1.1775 - val_loss: 2.3205 - val_state_user1_accuracy: 0.6627 - val_state_user1_loss: 0.8540 - val_state_user2_accuracy: 0.6191 - val_state_user2_loss: 1.5015
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 912ms/step - loss: 2.2882 - state_user1_accuracy: 0.6577 - state_user1_loss: 1.0000 - state_user2_accuracy: 0.6297 - state_user2_loss: 1.2050 - val_loss: 2.2672 - val_state_user1_accuracy: 0.6670 - val_state_user1_loss: 0.8434 - val_state_user2_accuracy: 0.6238 - val_state_user2_loss: 1.4536
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 888ms/step - loss: 2.2395 - state_user1_accuracy: 0.6533 - state_user1_loss: 0.9778 - state_user2_accuracy: 0.6487 - state_user2_loss: 1.1789 - val_loss: 2.3152 - val_state_user1_accuracy: 0.6695 - val_state_user1_loss: 0.8408 - val_state_user2_accuracy: 0.6250 - val_state_user2_loss: 1.4898
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 889ms/step - loss: 2.0674 - state_user1_accuracy: 0.6927 - state_user1_loss: 0.9261 - state_user2_accuracy: 0.6746 - state_user2_loss: 1.0589 - val_loss: 2.3470 - val_state_user1_accuracy: 0.6698 - val_state_user1_loss: 0.8465 - val_state_user2_accuracy: 0.6218 - val_state_user2_loss: 1.5255
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 951ms/step - loss: 2.1935 - state_user1_accuracy: 0.6755 - state_user1_loss: 0.9490 - state_user2_accuracy: 0.6315 - state_user2_loss: 1.1626 - val_loss: 2.2665 - val_state_user1_accuracy: 0.6717 - val_state_user1_loss: 0.8242 - val_state_user2_accuracy: 0.6265 - val_state_user2_loss: 1.4701
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 884ms/step - loss: 2.2862 - state_user1_accuracy: 0.6756 - state_user1_loss: 0.9796 - state_user2_accuracy: 0.6366 - state_user2_loss: 1.2251 - val_loss: 2.2382 - val_state_user1_accuracy: 0.6669 - val_state_user1_loss: 0.8336 - val_state_user2_accuracy: 0.6217 - val_state_user2_loss: 1.4628
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 972ms/step - loss: 2.1336 - state_user1_accuracy: 0.6634 - state_user1_loss: 0.9555 - state_user2_accuracy: 0.6622 - state_user2_loss: 1.0972 - val_loss: 2.2580 - val_state_user1_accuracy: 0.6669 - val_state_user1_loss: 0.8201 - val_state_user2_accuracy: 0.6193 - val_state_user2_loss: 1.4833
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 895ms/step - loss: 2.1366 - state_user1_accuracy: 0.6796 - state_user1_loss: 0.9353 - state_user2_accuracy: 0.6486 - state_user2_loss: 1.1207 - val_loss: 2.2982 - val_state_user1_accuracy: 0.6589 - val_state_user1_loss: 0.8315 - val_state_user2_accuracy: 0.6225 - val_state_user2_loss: 1.5024
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 864ms/step - loss: 2.1630 - state_user1_accuracy: 0.6753 - state_user1_loss: 0.9563 - state_user2_accuracy: 0.6369 - state_user2_loss: 1.1266 - val_loss: 2.2621 - val_state_user1_accuracy: 0.6619 - val_state_user1_loss: 0.8158 - val_state_user2_accuracy: 0.6312 - val_state_user2_loss: 1.4796
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step
# User1 Classification Report (Fold 3 ):
#               precision    recall  f1-score   support
#
#            0       0.64      0.72      0.68      7259
#            1       0.00      0.00      0.00       202
#            2       0.47      0.08      0.13      1046
#            3       0.07      0.04      0.05      1396
#            4       0.00      0.00      0.00       235
#            5       0.71      0.83      0.77     14183
# ...
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 5.3127 - state_user1_accuracy: 0.1830 - state_user1_loss: 2.4949 - state_user2_accuracy: 0.1849 - state_user2_loss: 2.7148 - val_loss: 3.7885 - val_state_user1_accuracy: 0.4260 - val_state_user1_loss: 1.8367 - val_state_user2_accuracy: 0.5414 - val_state_user2_loss: 1.8508
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - loss: 4.0216 - state_user1_accuracy: 0.3341 - state_user1_loss: 1.9746 - state_user2_accuracy: 0.3587 - state_user2_loss: 1.9558 - val_loss: 3.6123 - val_state_user1_accuracy: 0.5770 - val_state_user1_loss: 1.7572 - val_state_user2_accuracy: 0.6716 - val_state_user2_loss: 1.7600
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - loss: 3.5305 - state_user1_accuracy: 0.4566 - state_user1_loss: 1.6745 - state_user2_accuracy: 0.4597 - state_user2_loss: 1.7594 - val_loss: 3.4682 - val_state_user1_accuracy: 0.6137 - val_state_user1_loss: 1.6816 - val_state_user2_accuracy: 0.6929 - val_state_user2_loss: 1.6949
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 994ms/step - loss: 3.4486 - state_user1_accuracy: 0.4831 - state_user1_loss: 1.6092 - state_user2_accuracy: 0.4719 - state_user2_loss: 1.7430 - val_loss: 3.3563 - val_state_user1_accuracy: 0.6270 - val_state_user1_loss: 1.6074 - val_state_user2_accuracy: 0.6936 - val_state_user2_loss: 1.6553
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 986ms/step - loss: 3.1978 - state_user1_accuracy: 0.5343 - state_user1_loss: 1.4647 - state_user2_accuracy: 0.5097 - state_user2_loss: 1.6379 - val_loss: 3.2194 - val_state_user1_accuracy: 0.6172 - val_state_user1_loss: 1.5324 - val_state_user2_accuracy: 0.6963 - val_state_user2_loss: 1.5873
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - loss: 3.0558 - state_user1_accuracy: 0.5868 - state_user1_loss: 1.3071 - state_user2_accuracy: 0.5069 - state_user2_loss: 1.6511 - val_loss: 3.0753 - val_state_user1_accuracy: 0.5972 - val_state_user1_loss: 1.4465 - val_state_user2_accuracy: 0.6976 - val_state_user2_loss: 1.5240
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 988ms/step - loss: 3.0381 - state_user1_accuracy: 0.5688 - state_user1_loss: 1.3631 - state_user2_accuracy: 0.5441 - state_user2_loss: 1.5807 - val_loss: 2.8799 - val_state_user1_accuracy: 0.6458 - val_state_user1_loss: 1.3282 - val_state_user2_accuracy: 0.7079 - val_state_user2_loss: 1.4483
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 999ms/step - loss: 3.0010 - state_user1_accuracy: 0.5985 - state_user1_loss: 1.2524 - state_user2_accuracy: 0.5387 - state_user2_loss: 1.6553 - val_loss: 2.7981 - val_state_user1_accuracy: 0.6193 - val_state_user1_loss: 1.2583 - val_state_user2_accuracy: 0.7061 - val_state_user2_loss: 1.4256
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - loss: 2.7842 - state_user1_accuracy: 0.6096 - state_user1_loss: 1.2350 - state_user2_accuracy: 0.5854 - state_user2_loss: 1.4591 - val_loss: 2.7299 - val_state_user1_accuracy: 0.6329 - val_state_user1_loss: 1.2248 - val_state_user2_accuracy: 0.7068 - val_state_user2_loss: 1.3928
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - loss: 2.8448 - state_user1_accuracy: 0.6146 - state_user1_loss: 1.2305 - state_user2_accuracy: 0.5843 - state_user2_loss: 1.5207 - val_loss: 2.6424 - val_state_user1_accuracy: 0.6136 - val_state_user1_loss: 1.1626 - val_state_user2_accuracy: 0.7064 - val_state_user2_loss: 1.3669
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - loss: 2.7577 - state_user1_accuracy: 0.6393 - state_user1_loss: 1.1279 - state_user2_accuracy: 0.5642 - state_user2_loss: 1.5386 - val_loss: 2.5920 - val_state_user1_accuracy: 0.6161 - val_state_user1_loss: 1.1273 - val_state_user2_accuracy: 0.7054 - val_state_user2_loss: 1.3564
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - loss: 2.6573 - state_user1_accuracy: 0.6432 - state_user1_loss: 1.0998 - state_user2_accuracy: 0.5683 - state_user2_loss: 1.4669 - val_loss: 2.5706 - val_state_user1_accuracy: 0.5976 - val_state_user1_loss: 1.1360 - val_state_user2_accuracy: 0.6690 - val_state_user2_loss: 1.3086
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - loss: 2.4713 - state_user1_accuracy: 0.6550 - state_user1_loss: 1.0688 - state_user2_accuracy: 0.6183 - state_user2_loss: 1.3192 - val_loss: 2.5158 - val_state_user1_accuracy: 0.6048 - val_state_user1_loss: 1.0976 - val_state_user2_accuracy: 0.6814 - val_state_user2_loss: 1.2971
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - loss: 2.3869 - state_user1_accuracy: 0.6796 - state_user1_loss: 0.9988 - state_user2_accuracy: 0.6171 - state_user2_loss: 1.3029 - val_loss: 2.4866 - val_state_user1_accuracy: 0.6139 - val_state_user1_loss: 1.0680 - val_state_user2_accuracy: 0.6774 - val_state_user2_loss: 1.3009
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - loss: 2.4595 - state_user1_accuracy: 0.6765 - state_user1_loss: 1.0191 - state_user2_accuracy: 0.6076 - state_user2_loss: 1.3568 - val_loss: 2.4630 - val_state_user1_accuracy: 0.6115 - val_state_user1_loss: 1.0483 - val_state_user2_accuracy: 0.6671 - val_state_user2_loss: 1.2862
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - loss: 2.4725 - state_user1_accuracy: 0.6576 - state_user1_loss: 1.0652 - state_user2_accuracy: 0.6101 - state_user2_loss: 1.3297 - val_loss: 2.4008 - val_state_user1_accuracy: 0.6417 - val_state_user1_loss: 1.0188 - val_state_user2_accuracy: 0.6694 - val_state_user2_loss: 1.2727
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - loss: 2.4508 - state_user1_accuracy: 0.6507 - state_user1_loss: 1.0318 - state_user2_accuracy: 0.5794 - state_user2_loss: 1.3308 - val_loss: 2.3799 - val_state_user1_accuracy: 0.6059 - val_state_user1_loss: 1.0295 - val_state_user2_accuracy: 0.6725 - val_state_user2_loss: 1.2227
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - loss: 2.3721 - state_user1_accuracy: 0.6666 - state_user1_loss: 0.9912 - state_user2_accuracy: 0.6153 - state_user2_loss: 1.2965 - val_loss: 2.3296 - val_state_user1_accuracy: 0.6110 - val_state_user1_loss: 1.0319 - val_state_user2_accuracy: 0.6953 - val_state_user2_loss: 1.1781
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - loss: 2.4711 - state_user1_accuracy: 0.6585 - state_user1_loss: 1.0197 - state_user2_accuracy: 0.5915 - state_user2_loss: 1.3675 - val_loss: 2.3152 - val_state_user1_accuracy: 0.6255 - val_state_user1_loss: 1.0224 - val_state_user2_accuracy: 0.6897 - val_state_user2_loss: 1.1734
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - loss: 2.2917 - state_user1_accuracy: 0.6737 - state_user1_loss: 0.9872 - state_user2_accuracy: 0.6213 - state_user2_loss: 1.2246 - val_loss: 2.2887 - val_state_user1_accuracy: 0.6159 - val_state_user1_loss: 1.0248 - val_state_user2_accuracy: 0.6618 - val_state_user2_loss: 1.1432
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - loss: 2.2389 - state_user1_accuracy: 0.6737 - state_user1_loss: 0.9625 - state_user2_accuracy: 0.6335 - state_user2_loss: 1.1935 - val_loss: 2.2711 - val_state_user1_accuracy: 0.6511 - val_state_user1_loss: 1.0204 - val_state_user2_accuracy: 0.6859 - val_state_user2_loss: 1.1389
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - loss: 2.2239 - state_user1_accuracy: 0.6700 - state_user1_loss: 0.9771 - state_user2_accuracy: 0.6378 - state_user2_loss: 1.1671 - val_loss: 2.2258 - val_state_user1_accuracy: 0.6551 - val_state_user1_loss: 1.0045 - val_state_user2_accuracy: 0.6909 - val_state_user2_loss: 1.1137
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - loss: 2.3502 - state_user1_accuracy: 0.6710 - state_user1_loss: 0.9617 - state_user2_accuracy: 0.5864 - state_user2_loss: 1.3061 - val_loss: 2.2651 - val_state_user1_accuracy: 0.6025 - val_state_user1_loss: 1.0291 - val_state_user2_accuracy: 0.6995 - val_state_user2_loss: 1.1113
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - loss: 2.2243 - state_user1_accuracy: 0.6879 - state_user1_loss: 0.9215 - state_user2_accuracy: 0.6056 - state_user2_loss: 1.2216 - val_loss: 2.2021 - val_state_user1_accuracy: 0.6298 - val_state_user1_loss: 1.0088 - val_state_user2_accuracy: 0.6844 - val_state_user2_loss: 1.0829
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - loss: 2.3863 - state_user1_accuracy: 0.6546 - state_user1_loss: 1.0682 - state_user2_accuracy: 0.6040 - state_user2_loss: 1.2401 - val_loss: 2.2359 - val_state_user1_accuracy: 0.6370 - val_state_user1_loss: 1.0294 - val_state_user2_accuracy: 0.6848 - val_state_user2_loss: 1.0730
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 989ms/step - loss: 2.2155 - state_user1_accuracy: 0.6885 - state_user1_loss: 0.9158 - state_user2_accuracy: 0.5960 - state_user2_loss: 1.2202 - val_loss: 2.1850 - val_state_user1_accuracy: 0.6340 - val_state_user1_loss: 1.0113 - val_state_user2_accuracy: 0.6986 - val_state_user2_loss: 1.0525
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - loss: 2.1165 - state_user1_accuracy: 0.6865 - state_user1_loss: 0.9155 - state_user2_accuracy: 0.6364 - state_user2_loss: 1.1234 - val_loss: 2.1871 - val_state_user1_accuracy: 0.6416 - val_state_user1_loss: 1.0091 - val_state_user2_accuracy: 0.6747 - val_state_user2_loss: 1.0666
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 987ms/step - loss: 2.1164 - state_user1_accuracy: 0.6622 - state_user1_loss: 0.9464 - state_user2_accuracy: 0.6472 - state_user2_loss: 1.0916 - val_loss: 2.1963 - val_state_user1_accuracy: 0.6347 - val_state_user1_loss: 1.0256 - val_state_user2_accuracy: 0.6782 - val_state_user2_loss: 1.0473
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 996ms/step - loss: 2.1961 - state_user1_accuracy: 0.6861 - state_user1_loss: 0.8881 - state_user2_accuracy: 0.5844 - state_user2_loss: 1.2304 - val_loss: 2.1980 - val_state_user1_accuracy: 0.6364 - val_state_user1_loss: 1.0225 - val_state_user2_accuracy: 0.6817 - val_state_user2_loss: 1.0555
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000024DA66AC900> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 823ms/step
# User1 Classification Report (Fold 5 ):
#               precision    recall  f1-score   support
#
#            0       0.82      0.61      0.70      9426
#            1       0.00      0.00      0.00       283
#            2       0.27      0.02      0.03      1013
#            3       0.32      0.10      0.16      2163
#            4       0.00      0.00      0.00       326
#            5       0.58      0.91      0.71     11271
#            6       0.35      0.11      0.17      1438
#
#     accuracy                           0.63     25920
#    macro avg       0.33      0.25      0.25     25920
# weighted avg       0.61      0.63      0.59     25920
#
#
# User2 Classification Report (Fold 5 ):
#               precision    recall  f1-score   support
#
#            0       0.90      0.73      0.81     14501
#            1       0.00      0.00      0.00       396
#            2       0.00      0.00      0.00       925
#            3       0.00      0.00      0.00      1349
#            4       0.00      0.00      0.00        12
#            5       0.53      0.95      0.68      7908
#            6       0.00      0.00      0.00       829
#
#     accuracy                           0.70     25920
#    macro avg       0.20      0.24      0.21     25920
# weighted avg       0.67      0.70      0.66     25920
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Compute and print average F1-scores across folds (only for class labels, not averages)
def compute_avg_f1(reports):
    avg_f1 = {}
    first_report = reports[0]

    for label in first_report.keys():
        if isinstance(first_report[label], dict) and "f1-score" in first_report[label]:  # Exclude non-dictionary values
            f1_scores = [rep[label]['f1-score'] for rep in reports if label in rep]  # Check if label exists in each report
            if f1_scores:  # Ensure the list is not empty before averaging
                avg_f1[label] = np.mean(f1_scores)
    
    return avg_f1

# Get average F1-score for User1 and User2
avg_report_user1 = compute_avg_f1(user1_reports)
avg_report_user2 = compute_avg_f1(user2_reports)

print("\n🔹 Average F1-Scores Across Folds for User1:")
for label, f1 in avg_report_user1.items():
    print(f"Class {label}: {f1:.4f}")

print("\n🔹 Average F1-Scores Across Folds for User2:")
for label, f1 in avg_report_user2.items():
    print(f"Class {label}: {f1:.4f}")
# Out:
# 🔹 Average F1-Scores Across Folds for User1:
# Class 0: 0.7072
# Class 1: 0.0000
# Class 2: 0.0323
# Class 3: 0.0963
# Class 4: 0.0000
# Class 5: 0.7664
# Class 6: 0.1300
# Class macro avg: 0.2474
# Class weighted avg: 0.6196
#
# 🔹 Average F1-Scores Across Folds for User2:
# Class 0: 0.6956
# Class 1: 0.0000
# Class 2: 0.0000
# Class 3: 0.0000
# Class 4: 0.0000
# Class 5: 0.6592
# Class 6: 0.0000
# Class macro avg: 0.1935
# Class weighted avg: 0.5894

# %%
# Build a final model on the entire dataset
final_model = create_lstm_model(
    input_shape=(X.shape[1], X.shape[2]),
    num_states_user1=num_states_user1,
    num_states_user2=num_states_user2
)

early_stop_final = tf.keras.callbacks.EarlyStopping(
    monitor="loss",
    patience=3,
    restore_best_weights=True
)

final_model.fit(
    X,
    {"state_user1": y1, "state_user2": y2},
    epochs=100,
    batch_size=4,
    callbacks=[early_stop_final]
)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 18s 927ms/step - loss: 5.1029 - state_user1_accuracy: 0.1496 - state_user1_loss: 2.7177 - state_user2_accuracy: 0.2736 - state_user2_loss: 2.2858
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 937ms/step - loss: 3.8539 - state_user1_accuracy: 0.3735 - state_user1_loss: 1.8755 - state_user2_accuracy: 0.4061 - state_user2_loss: 1.8815
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 934ms/step - loss: 3.3445 - state_user1_accuracy: 0.4867 - state_user1_loss: 1.5599 - state_user2_accuracy: 0.4986 - state_user2_loss: 1.6879
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 930ms/step - loss: 3.0719 - state_user1_accuracy: 0.5633 - state_user1_loss: 1.3770 - state_user2_accuracy: 0.5457 - state_user2_loss: 1.5977
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 933ms/step - loss: 2.9734 - state_user1_accuracy: 0.5679 - state_user1_loss: 1.3509 - state_user2_accuracy: 0.5612 - state_user2_loss: 1.5278
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 935ms/step - loss: 2.9371 - state_user1_accuracy: 0.6096 - state_user1_loss: 1.2598 - state_user2_accuracy: 0.5509 - state_user2_loss: 1.5817
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 928ms/step - loss: 2.7541 - state_user1_accuracy: 0.6229 - state_user1_loss: 1.2362 - state_user2_accuracy: 0.6045 - state_user2_loss: 1.4251
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 925ms/step - loss: 2.7285 - state_user1_accuracy: 0.6373 - state_user1_loss: 1.1458 - state_user2_accuracy: 0.5758 - state_user2_loss: 1.4900
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 927ms/step - loss: 2.5807 - state_user1_accuracy: 0.6514 - state_user1_loss: 1.1133 - state_user2_accuracy: 0.6017 - state_user2_loss: 1.3765
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 923ms/step - loss: 2.7522 - state_user1_accuracy: 0.6225 - state_user1_loss: 1.1751 - state_user2_accuracy: 0.5812 - state_user2_loss: 1.4860
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 920ms/step - loss: 2.5901 - state_user1_accuracy: 0.6629 - state_user1_loss: 1.0624 - state_user2_accuracy: 0.5827 - state_user2_loss: 1.4377
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 936ms/step - loss: 2.4703 - state_user1_accuracy: 0.6366 - state_user1_loss: 1.0923 - state_user2_accuracy: 0.6304 - state_user2_loss: 1.2902
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 939ms/step - loss: 2.5278 - state_user1_accuracy: 0.6431 - state_user1_loss: 1.1322 - state_user2_accuracy: 0.6114 - state_user2_loss: 1.3079
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 938ms/step - loss: 2.3798 - state_user1_accuracy: 0.6717 - state_user1_loss: 0.9911 - state_user2_accuracy: 0.6068 - state_user2_loss: 1.3014
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 927ms/step - loss: 2.3259 - state_user1_accuracy: 0.6853 - state_user1_loss: 0.9719 - state_user2_accuracy: 0.6079 - state_user2_loss: 1.2675
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 921ms/step - loss: 2.3448 - state_user1_accuracy: 0.6596 - state_user1_loss: 0.9867 - state_user2_accuracy: 0.6183 - state_user2_loss: 1.2728
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 942ms/step - loss: 2.4532 - state_user1_accuracy: 0.6472 - state_user1_loss: 1.0514 - state_user2_accuracy: 0.5886 - state_user2_loss: 1.3176
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 940ms/step - loss: 2.1963 - state_user1_accuracy: 0.6835 - state_user1_loss: 0.9420 - state_user2_accuracy: 0.6384 - state_user2_loss: 1.1713
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 929ms/step - loss: 2.2633 - state_user1_accuracy: 0.6675 - state_user1_loss: 0.9612 - state_user2_accuracy: 0.6047 - state_user2_loss: 1.2209
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 936ms/step - loss: 2.3109 - state_user1_accuracy: 0.6450 - state_user1_loss: 1.0237 - state_user2_accuracy: 0.6183 - state_user2_loss: 1.2054
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 935ms/step - loss: 2.1957 - state_user1_accuracy: 0.6781 - state_user1_loss: 0.9677 - state_user2_accuracy: 0.6344 - state_user2_loss: 1.1476
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 944ms/step - loss: 2.1687 - state_user1_accuracy: 0.6577 - state_user1_loss: 0.9811 - state_user2_accuracy: 0.6461 - state_user2_loss: 1.1075
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 929ms/step - loss: 2.2029 - state_user1_accuracy: 0.6472 - state_user1_loss: 0.9942 - state_user2_accuracy: 0.6426 - state_user2_loss: 1.1305
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 937ms/step - loss: 2.1525 - state_user1_accuracy: 0.6498 - state_user1_loss: 0.9970 - state_user2_accuracy: 0.6604 - state_user2_loss: 1.0775
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 924ms/step - loss: 2.1359 - state_user1_accuracy: 0.6593 - state_user1_loss: 0.9827 - state_user2_accuracy: 0.6558 - state_user2_loss: 1.0754
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 919ms/step - loss: 2.1405 - state_user1_accuracy: 0.6843 - state_user1_loss: 0.8811 - state_user2_accuracy: 0.6044 - state_user2_loss: 1.1830
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 922ms/step - loss: 2.0760 - state_user1_accuracy: 0.6946 - state_user1_loss: 0.8879 - state_user2_accuracy: 0.6305 - state_user2_loss: 1.1129
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 933ms/step - loss: 1.9792 - state_user1_accuracy: 0.7056 - state_user1_loss: 0.8619 - state_user2_accuracy: 0.6513 - state_user2_loss: 1.0421
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 929ms/step - loss: 2.0546 - state_user1_accuracy: 0.6776 - state_user1_loss: 0.8872 - state_user2_accuracy: 0.6476 - state_user2_loss: 1.0933
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 936ms/step - loss: 1.9751 - state_user1_accuracy: 0.7023 - state_user1_loss: 0.8861 - state_user2_accuracy: 0.6560 - state_user2_loss: 1.0168
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 926ms/step - loss: 2.0113 - state_user1_accuracy: 0.6731 - state_user1_loss: 0.9118 - state_user2_accuracy: 0.6547 - state_user2_loss: 1.0270
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 926ms/step - loss: 2.0630 - state_user1_accuracy: 0.6625 - state_user1_loss: 0.9434 - state_user2_accuracy: 0.6505 - state_user2_loss: 1.0483
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 928ms/step - loss: 2.0365 - state_user1_accuracy: 0.7040 - state_user1_loss: 0.8614 - state_user2_accuracy: 0.6148 - state_user2_loss: 1.1047
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 927ms/step - loss: 2.0190 - state_user1_accuracy: 0.6692 - state_user1_loss: 0.9394 - state_user2_accuracy: 0.6631 - state_user2_loss: 1.0101
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 934ms/step - loss: 2.0225 - state_user1_accuracy: 0.6598 - state_user1_loss: 0.9322 - state_user2_accuracy: 0.6565 - state_user2_loss: 1.0211
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 921ms/step - loss: 2.0786 - state_user1_accuracy: 0.6836 - state_user1_loss: 0.8840 - state_user2_accuracy: 0.6020 - state_user2_loss: 1.1253
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 922ms/step - loss: 1.9987 - state_user1_accuracy: 0.6797 - state_user1_loss: 0.8764 - state_user2_accuracy: 0.6326 - state_user2_loss: 1.0540
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 930ms/step - loss: 1.9965 - state_user1_accuracy: 0.6932 - state_user1_loss: 0.8884 - state_user2_accuracy: 0.6424 - state_user2_loss: 1.0405
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 938ms/step - loss: 1.9773 - state_user1_accuracy: 0.6887 - state_user1_loss: 0.8652 - state_user2_accuracy: 0.6371 - state_user2_loss: 1.0462
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 935ms/step - loss: 2.0045 - state_user1_accuracy: 0.6616 - state_user1_loss: 0.9294 - state_user2_accuracy: 0.6631 - state_user2_loss: 1.0090
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 928ms/step - loss: 1.9682 - state_user1_accuracy: 0.6668 - state_user1_loss: 0.9261 - state_user2_accuracy: 0.6673 - state_user2_loss: 0.9771
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 930ms/step - loss: 1.9201 - state_user1_accuracy: 0.7030 - state_user1_loss: 0.8358 - state_user2_accuracy: 0.6506 - state_user2_loss: 1.0209
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 924ms/step - loss: 2.0425 - state_user1_accuracy: 0.6691 - state_user1_loss: 0.9177 - state_user2_accuracy: 0.6389 - state_user2_loss: 1.0623
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 933ms/step - loss: 1.9726 - state_user1_accuracy: 0.6731 - state_user1_loss: 0.9009 - state_user2_accuracy: 0.6544 - state_user2_loss: 1.0086
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 938ms/step - loss: 1.9489 - state_user1_accuracy: 0.6797 - state_user1_loss: 0.8980 - state_user2_accuracy: 0.6625 - state_user2_loss: 0.9888
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved final model to full_week_lstm_model.h5

# %%
# Save the final single model
final_model.save("full_week_lstm_model.keras")
